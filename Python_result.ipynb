# %%
import pandas as pd    
import re
from name_prediction.code import bleu

# %% [markdown]
# ### Testing data collection

# %%
# testing Java code 
modelTest = "/Users/fjirigesi/Documents/Polyglot/name_prediction/dataset/python/test.jsonl"
modelTestDF = pd.read_json(path_or_buf=modelTest, lines=True)
# all tested code information 
allJavaTest = "/Users/fjirigesi/Documents/Polyglot/combine/test_python.jsonl"
allJavaTestDF = pd.read_json(path_or_buf=allJavaTest, lines=True)

# save original method name
allJavaTestDF['origin_method_name'] = modelTestDF['docstring_tokens']
print(allJavaTestDF.shape)
# Out:
# (14918, 13)

# %%
allJavaTestDF.head()
# Out:
#               repo                                   path  \
# 0  soimort/you-get       src/you_get/extractors/miomio.py
# 1  soimort/you-get  src/you_get/extractors/dailymotion.py
# 2  soimort/you-get         src/you_get/extractors/sina.py
# 3  soimort/you-get                src/you_get/util/log.py
# 4  soimort/you-get                src/you_get/util/log.py
#
#               func_name                                    original_string  \
# 0  sina_xml_to_url_list  def sina_xml_to_url_list(xml_data):\n    """st...
# 1  dailymotion_download  def dailymotion_download(url, output_dir='.', ...
# 2         sina_download  def sina_download(url, output_dir='.', merge=T...
# 3                sprint  def sprint(text, *colors):\n    """Format text...
# 4             print_log  def print_log(text, *colors):\n    """Print a ...
#
#   language                                               code  \
# 0   python  def sina_xml_to_url_list(xml_data):\n    """st...
# 1   python  def dailymotion_download(url, output_dir='.', ...
# 2   python  def sina_download(url, output_dir='.', merge=T...
# 3   python  def sprint(text, *colors):\n    """Format text...
# 4   python  def print_log(text, *colors):\n    """Print a ...
#
#                                          code_tokens  \
# 0  [def, sina_xml_to_url_list, (, xml_data, ), :,...
# 1  [def, dailymotion_download, (, url, ,, output_...
# 2  [def, sina_download, (, url, ,, output_dir, =,...
# 3  [def, sprint, (, text, ,, *, colors, ), :, ret...
# 4  [def, print_log, (, text, ,, *, colors, ), :, ...
#
#                                            docstring  \
# 0  str->list\n    Convert XML to URL List.\n    F...
# 1               Downloads Dailymotion videos by URL.
# 2                      Downloads Sina videos by URL.
# 3  Format text with color or other effects into A...
# 4             Print a log message to standard error.
#
#                                     docstring_tokens  \
# 0  [str, -, >, list, Convert, XML, to, URL, List,...
# 1       [Downloads, Dailymotion, videos, by, URL, .]
# 2              [Downloads, Sina, videos, by, URL, .]
# 3  [Format, text, with, color, or, other, effects...
# 4   [Print, a, log, message, to, standard, error, .]
#
#                                         sha  \
# 0  b746ac01c9f39de94cac2d56f665285b0523b974
# 1  b746ac01c9f39de94cac2d56f665285b0523b974
# 2  b746ac01c9f39de94cac2d56f665285b0523b974
# 3  b746ac01c9f39de94cac2d56f665285b0523b974
# 4  b746ac01c9f39de94cac2d56f665285b0523b974
#
#                                                  url partition  \
# 0  https://github.com/soimort/you-get/blob/b746ac...      test
# 1  https://github.com/soimort/you-get/blob/b746ac...      test
# 2  https://github.com/soimort/you-get/blob/b746ac...      test
# 3  https://github.com/soimort/you-get/blob/b746ac...      test
# 4  https://github.com/soimort/you-get/blob/b746ac...      test
#
#        origin_method_name
# 0  [sina_xml_to_url_list]
# 1  [dailymotion_download]
# 2         [sina_download]
# 3                [sprint]
# 4             [print_log]

# %% [markdown]
# ### Extract predicted method names

# %%
def splitPuncts(line):
    return ' '.join(re.findall(r"[\w]+|[^\s\w]", line))

# %%
predict_file = "/Users/fjirigesi/Documents/Polyglot_result/python_output/test_1.output"

of = open(predict_file, 'r', encoding="utf-8")

predictMap = {}
idx = 0
predicted_method_names = []
for row in of:
    (rid, pred) = row.split('\t')
    predicted_method_names.append(pred.split('\n')[0])
    predictMap[rid] = []
    predictMap[rid].append(splitPuncts(pred.strip().lower()))

allJavaTestDF['predicted_method_names'] = predicted_method_names

# %%
allJavaTestDF
# Out:
#                                  repo                                   path  \
# 0                     soimort/you-get       src/you_get/extractors/miomio.py
# 1                     soimort/you-get  src/you_get/extractors/dailymotion.py
# 2                     soimort/you-get         src/you_get/extractors/sina.py
# 3                     soimort/you-get                src/you_get/util/log.py
# 4                     soimort/you-get                src/you_get/util/log.py
# ...                               ...                                    ...
# 14913  JIC-CSB/jicbioimage.illustrate     jicbioimage/illustrate/__init__.py
# 14914           un33k/django-toolware              toolware/utils/generic.py
# 14915           un33k/django-toolware              toolware/utils/generic.py
# 14916           un33k/django-toolware              toolware/utils/generic.py
# 14917           un33k/django-toolware              toolware/utils/generic.py
#
#                            func_name  \
# 0               sina_xml_to_url_list
# 1               dailymotion_download
# 2                      sina_download
# 3                             sprint
# 4                          print_log
# ...                              ...
# 14913  AnnotatedImage.from_grayscale
# 14914                       get_uuid
# 14915        get_unique_key_from_get
# 14916                     get_domain
# 14917                   get_url_args
#
#                                          original_string language  \
# 0      def sina_xml_to_url_list(xml_data):\n    """st...   python
# 1      def dailymotion_download(url, output_dir='.', ...   python
# 2      def sina_download(url, output_dir='.', merge=T...   python
# 3      def sprint(text, *colors):\n    """Format text...   python
# 4      def print_log(text, *colors):\n    """Print a ...   python
# ...                                                  ...      ...
# 14913  def from_grayscale(im, channels_on=(True, True...   python
# 14914  def get_uuid(length=32, version=1):\n    """\n...   python
# 14915  def get_unique_key_from_get(get_dict):\n    ""...   python
# 14916  def get_domain(url):\n    """ Returns domain n...   python
# 14917  def get_url_args(url):\n    """ Returns a dict...   python
#
#                                                     code  \
# 0      def sina_xml_to_url_list(xml_data):\n    """st...
# 1      def dailymotion_download(url, output_dir='.', ...
# 2      def sina_download(url, output_dir='.', merge=T...
# 3      def sprint(text, *colors):\n    """Format text...
# 4      def print_log(text, *colors):\n    """Print a ...
# ...                                                  ...
# 14913  def from_grayscale(im, channels_on=(True, True...
# 14914  def get_uuid(length=32, version=1):\n    """\n...
# 14915  def get_unique_key_from_get(get_dict):\n    ""...
# 14916  def get_domain(url):\n    """ Returns domain n...
# 14917  def get_url_args(url):\n    """ Returns a dict...
#
#                                              code_tokens  \
# 0      [def, sina_xml_to_url_list, (, xml_data, ), :,...
# 1      [def, dailymotion_download, (, url, ,, output_...
# 2      [def, sina_download, (, url, ,, output_dir, =,...
# 3      [def, sprint, (, text, ,, *, colors, ), :, ret...
# 4      [def, print_log, (, text, ,, *, colors, ), :, ...
# ...                                                  ...
# 14913  [def, from_grayscale, (, im, ,, channels_on, =...
# 14914  [def, get_uuid, (, length, =, 32, ,, version, ...
# 14915  [def, get_unique_key_from_get, (, get_dict, ),...
# 14916  [def, get_domain, (, url, ), :, if, 'http', no...
# 14917  [def, get_url_args, (, url, ), :, url_data, =,...
#
#                                                docstring  \
# 0      str->list\n    Convert XML to URL List.\n    F...
# 1                   Downloads Dailymotion videos by URL.
# 2                          Downloads Sina videos by URL.
# 3      Format text with color or other effects into A...
# 4                 Print a log message to standard error.
# ...                                                  ...
# 14913  Return a canvas from a grayscale image.\n\n   ...
# 14914  Returns a unique ID of a given length.\n    Us...
# 14915                   Build a unique key from get data
# 14916               Returns domain name portion of a URL
# 14917             Returns a dictionary from a URL params
#
#                                         docstring_tokens  \
# 0      [str, -, >, list, Convert, XML, to, URL, List,...
# 1           [Downloads, Dailymotion, videos, by, URL, .]
# 2                  [Downloads, Sina, videos, by, URL, .]
# 3      [Format, text, with, color, or, other, effects...
# 4       [Print, a, log, message, to, standard, error, .]
# ...                                                  ...
# 14913  [Return, a, canvas, from, a, grayscale, image, .]
# 14914  [Returns, a, unique, ID, of, a, given, length,...
# 14915           [Build, a, unique, key, from, get, data]
# 14916       [Returns, domain, name, portion, of, a, URL]
# 14917     [Returns, a, dictionary, from, a, URL, params]
#
#                                             sha  \
# 0      b746ac01c9f39de94cac2d56f665285b0523b974
# 1      b746ac01c9f39de94cac2d56f665285b0523b974
# 2      b746ac01c9f39de94cac2d56f665285b0523b974
# 3      b746ac01c9f39de94cac2d56f665285b0523b974
# 4      b746ac01c9f39de94cac2d56f665285b0523b974
# ...                                         ...
# 14913  d88ddf81ee3eb3949677e2ef746af8169ce88092
# 14914  973f3e003dc38b812897dab88455bee37dcaf931
# 14915  973f3e003dc38b812897dab88455bee37dcaf931
# 14916  973f3e003dc38b812897dab88455bee37dcaf931
# 14917  973f3e003dc38b812897dab88455bee37dcaf931
#
#                                                      url partition  \
# 0      https://github.com/soimort/you-get/blob/b746ac...      test
# 1      https://github.com/soimort/you-get/blob/b746ac...      test
# 2      https://github.com/soimort/you-get/blob/b746ac...      test
# 3      https://github.com/soimort/you-get/blob/b746ac...      test
# 4      https://github.com/soimort/you-get/blob/b746ac...      test
# ...                                                  ...       ...
# 14913  https://github.com/JIC-CSB/jicbioimage.illustr...      test
# 14914  https://github.com/un33k/django-toolware/blob/...      test
# 14915  https://github.com/un33k/django-toolware/blob/...      test
# 14916  https://github.com/un33k/django-toolware/blob/...      test
# 14917  https://github.com/un33k/django-toolware/blob/...      test
#
#               origin_method_name predicted_method_names
# 0         [sina_xml_to_url_list]         parse  raw url
# 1         [dailymotion_download]                process
# 2                [sina_download]            s ina  info
# 3                       [sprint]              color ize
# 4                    [print_log]                    log
# ...                          ...                    ...
# 14913           [from_grayscale]              annot ate
# 14914                 [get_uuid]       gener ate  uu id
# 14915  [get_unique_key_from_get]        get  cache  key
# 14916               [get_domain]         get  host name
# 14917             [get_url_args]         get  url  dict
#
# [14918 rows x 14 columns]

# %% [markdown]
# ### Calculate scores for prediected method names

# %%
dev_gold_file = "/Users/fjirigesi/Documents/Polyglot_result/python_output/test_1.gold"

gf = open(dev_gold_file, 'r', encoding="utf-8")

goldMap = {}
idx = 0
original_method_names = []
for row in gf:
    (rid, ori) = row.split('\t') 
    original_method_names.append(ori.split('\n')[0])
    goldMap[rid] = []
    goldMap[rid].append(splitPuncts(ori.strip().lower()))
print(len(original_method_names))
# Out:
# 14918

# %%
def calculate(original_name, predict_name):
    #split words
    x = original_name.split()
    x = list(original_name)
    y = predict_name.split()
    y = list(predict_name)
    #calculate common chars 
    common = []
    
    for ch in x:
        if ch in y:
            common.append(ch)
    # char in candidate, but not in predicted word 
    FN_list = []
    for w in x:
        if w not in common:
            FN_list.append(w)
    # char in predicted word, but not in candidate 
    FP_list=[]
    for w in y:
        if w not in common:
            FP_list.append(w)

    # calculate precision, recall and fscore
    TP=len(common)
    FP=len(FP_list)
    FN=len(FN_list)

    if TP==0:
        prec=0.0
        recall=0.0
        fscore=0.0
    else:
        prec=TP/(TP+FP)*1.0
        recall=TP/(TP+FN)*1.0
        fscore=2.0*prec*recall/(prec+recall)

    return (prec, recall, fscore)

# %%
precesions = []
recalls = []
fscores = []

number_samples = len(original_method_names)

for i in range(number_samples):
    prec, recall, fscore = calculate(original_method_names[i], predicted_method_names[i])
    precesions.append(prec)
    recalls.append(recall)
    fscores.append(fscore)
    
allJavaTestDF['precision'] = precesions
allJavaTestDF['recall'] = recalls
allJavaTestDF['fscore'] = fscores

# %%
allJavaTestDF
# Out:
#                                  repo                                   path  \
# 0                     soimort/you-get       src/you_get/extractors/miomio.py
# 1                     soimort/you-get  src/you_get/extractors/dailymotion.py
# 2                     soimort/you-get         src/you_get/extractors/sina.py
# 3                     soimort/you-get                src/you_get/util/log.py
# 4                     soimort/you-get                src/you_get/util/log.py
# ...                               ...                                    ...
# 14913  JIC-CSB/jicbioimage.illustrate     jicbioimage/illustrate/__init__.py
# 14914           un33k/django-toolware              toolware/utils/generic.py
# 14915           un33k/django-toolware              toolware/utils/generic.py
# 14916           un33k/django-toolware              toolware/utils/generic.py
# 14917           un33k/django-toolware              toolware/utils/generic.py
#
#                            func_name  \
# 0               sina_xml_to_url_list
# 1               dailymotion_download
# 2                      sina_download
# 3                             sprint
# 4                          print_log
# ...                              ...
# 14913  AnnotatedImage.from_grayscale
# 14914                       get_uuid
# 14915        get_unique_key_from_get
# 14916                     get_domain
# 14917                   get_url_args
#
#                                          original_string language  \
# 0      def sina_xml_to_url_list(xml_data):\n    """st...   python
# 1      def dailymotion_download(url, output_dir='.', ...   python
# 2      def sina_download(url, output_dir='.', merge=T...   python
# 3      def sprint(text, *colors):\n    """Format text...   python
# 4      def print_log(text, *colors):\n    """Print a ...   python
# ...                                                  ...      ...
# 14913  def from_grayscale(im, channels_on=(True, True...   python
# 14914  def get_uuid(length=32, version=1):\n    """\n...   python
# 14915  def get_unique_key_from_get(get_dict):\n    ""...   python
# 14916  def get_domain(url):\n    """ Returns domain n...   python
# 14917  def get_url_args(url):\n    """ Returns a dict...   python
#
#                                                     code  \
# 0      def sina_xml_to_url_list(xml_data):\n    """st...
# 1      def dailymotion_download(url, output_dir='.', ...
# 2      def sina_download(url, output_dir='.', merge=T...
# 3      def sprint(text, *colors):\n    """Format text...
# 4      def print_log(text, *colors):\n    """Print a ...
# ...                                                  ...
# 14913  def from_grayscale(im, channels_on=(True, True...
# 14914  def get_uuid(length=32, version=1):\n    """\n...
# 14915  def get_unique_key_from_get(get_dict):\n    ""...
# 14916  def get_domain(url):\n    """ Returns domain n...
# 14917  def get_url_args(url):\n    """ Returns a dict...
#
#                                              code_tokens  \
# 0      [def, sina_xml_to_url_list, (, xml_data, ), :,...
# 1      [def, dailymotion_download, (, url, ,, output_...
# 2      [def, sina_download, (, url, ,, output_dir, =,...
# 3      [def, sprint, (, text, ,, *, colors, ), :, ret...
# 4      [def, print_log, (, text, ,, *, colors, ), :, ...
# ...                                                  ...
# 14913  [def, from_grayscale, (, im, ,, channels_on, =...
# 14914  [def, get_uuid, (, length, =, 32, ,, version, ...
# 14915  [def, get_unique_key_from_get, (, get_dict, ),...
# 14916  [def, get_domain, (, url, ), :, if, 'http', no...
# 14917  [def, get_url_args, (, url, ), :, url_data, =,...
#
#                                                docstring  \
# 0      str->list\n    Convert XML to URL List.\n    F...
# 1                   Downloads Dailymotion videos by URL.
# 2                          Downloads Sina videos by URL.
# 3      Format text with color or other effects into A...
# 4                 Print a log message to standard error.
# ...                                                  ...
# 14913  Return a canvas from a grayscale image.\n\n   ...
# 14914  Returns a unique ID of a given length.\n    Us...
# 14915                   Build a unique key from get data
# 14916               Returns domain name portion of a URL
# 14917             Returns a dictionary from a URL params
#
#                                         docstring_tokens  \
# 0      [str, -, >, list, Convert, XML, to, URL, List,...
# 1           [Downloads, Dailymotion, videos, by, URL, .]
# 2                  [Downloads, Sina, videos, by, URL, .]
# 3      [Format, text, with, color, or, other, effects...
# 4       [Print, a, log, message, to, standard, error, .]
# ...                                                  ...
# 14913  [Return, a, canvas, from, a, grayscale, image, .]
# 14914  [Returns, a, unique, ID, of, a, given, length,...
# 14915           [Build, a, unique, key, from, get, data]
# 14916       [Returns, domain, name, portion, of, a, URL]
# 14917     [Returns, a, dictionary, from, a, URL, params]
#
#                                             sha  \
# 0      b746ac01c9f39de94cac2d56f665285b0523b974
# 1      b746ac01c9f39de94cac2d56f665285b0523b974
# 2      b746ac01c9f39de94cac2d56f665285b0523b974
# 3      b746ac01c9f39de94cac2d56f665285b0523b974
# 4      b746ac01c9f39de94cac2d56f665285b0523b974
# ...                                         ...
# 14913  d88ddf81ee3eb3949677e2ef746af8169ce88092
# 14914  973f3e003dc38b812897dab88455bee37dcaf931
# 14915  973f3e003dc38b812897dab88455bee37dcaf931
# 14916  973f3e003dc38b812897dab88455bee37dcaf931
# 14917  973f3e003dc38b812897dab88455bee37dcaf931
#
#                                                      url partition  \
# 0      https://github.com/soimort/you-get/blob/b746ac...      test
# 1      https://github.com/soimort/you-get/blob/b746ac...      test
# 2      https://github.com/soimort/you-get/blob/b746ac...      test
# 3      https://github.com/soimort/you-get/blob/b746ac...      test
# 4      https://github.com/soimort/you-get/blob/b746ac...      test
# ...                                                  ...       ...
# 14913  https://github.com/JIC-CSB/jicbioimage.illustr...      test
# 14914  https://github.com/un33k/django-toolware/blob/...      test
# 14915  https://github.com/un33k/django-toolware/blob/...      test
# 14916  https://github.com/un33k/django-toolware/blob/...      test
# 14917  https://github.com/un33k/django-toolware/blob/...      test
#
#               origin_method_name predicted_method_names  precision    recall  \
# 0         [sina_xml_to_url_list]         parse  raw url   0.812500  0.619048
# 1         [dailymotion_download]                process   0.400000  0.190476
# 2                [sina_download]            s ina  info   0.909091  0.714286
# 3                       [sprint]              color ize   0.333333  0.428571
# 4                    [print_log]                    log   1.000000  0.333333
# ...                          ...                    ...        ...       ...
# 14913           [from_grayscale]              annot ate   0.636364  0.437500
# 14914                 [get_uuid]       gener ate  uu id   0.750000  1.000000
# 14915  [get_unique_key_from_get]        get  cache  key   0.777778  0.608696
# 14916               [get_domain]         get  host name   0.800000  0.800000
# 14917             [get_url_args]         get  url  dict   0.769231  0.833333
#
#          fscore
# 0      0.702703
# 1      0.258065
# 2      0.800000
# 3      0.375000
# 4      0.500000
# ...         ...
# 14913  0.518519
# 14914  0.857143
# 14915  0.682927
# 14916  0.800000
# 14917  0.800000
#
# [14918 rows x 17 columns]

# %%
allJavaTestDF.to_csv('python_result_v1.csv')

# %%
allJavaTestDF.iloc[0]['url']
# Out:
# 'https://github.com/soimort/you-get/blob/b746ac01c9f39de94cac2d56f665285b0523b974/src/you_get/extractors/miomio.py#L41-L51'
